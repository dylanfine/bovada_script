# %%
import requests

# %%
url = 'https://www.bovada.lv/services/sports/event/v2/events/A/description/football/nfl?lang=en'
#HTTPS Request - returns data
res = requests.get(url)
print(res)
#200 Status means response successful
print(res.reason)
# Out:
# <Response [200]>
# OK

# %%
#Data is returned in JSON format to be interepreted
data = res.json()

# %%
data[0].keys()
# Out:
# dict_keys(['path', 'events'])

# %%
#This doesn't give us anything
data[0]['path']
# Out:
# [{'id': '241',
#   'link': '/football/nfl',
#   'description': 'NFL',
#   'type': 'LEAGUE',
#   'sportCode': 'FOOT',
#   'order': 1,
#   'leaf': True,
#   'current': True},
#  {'id': '1',
#   'link': '/football',
#   'description': 'Football',
#   'type': 'SPORT',
#   'sportCode': 'FOOT',
#   'order': 6,
#   'leaf': False,
#   'current': False}]

# %%
#events looks like an array of each game
for i in data[0]['events']:
    print(i['description'])
# Out:
# Los Angeles Rams @ Seattle Seahawks
# New York Jets @ Atlanta Falcons
# Denver Broncos @ Pittsburgh Steelers
# Detroit Lions @ Minnesota Vikings
# Green Bay Packers @ Cincinnati Bengals
# Miami Dolphins @ Tampa Bay Buccaneers
# New England Patriots @ Houston Texans
# New Orleans Saints @ Washington Football Team
# Philadelphia Eagles @ Carolina Panthers
# Tennessee Titans @ Jacksonville Jaguars
# Chicago Bears @ Las Vegas Raiders
# Cleveland Browns @ Los Angeles Chargers
# New York Giants @ Dallas Cowboys
# San Francisco 49ers @ Arizona Cardinals
# Buffalo Bills @ Kansas City Chiefs
# Indianapolis Colts @ Baltimore Ravens

# %%
#Further explore the first game
game_0 = data[0]['events'][0]
game_0.keys()
# Out:
# dict_keys(['id', 'description', 'type', 'link', 'status', 'sport', 'startTime', 'live', 'awayTeamFirst', 'denySameGame', 'teaserAllowed', 'competitionId', 'notes', 'numMarkets', 'lastModified', 'competitors', 'displayGroups'])

# %%
#displayGroups looks like it has all the markets
bets = game_0['displayGroups']

# %%
#Differnet categories seen on bovada's website
for x in bets:
    print(x['description'])
# Out:
# Game Lines
# Alternate Lines
# Special Bets
# Score Props
# Receiving Props
# Quarterback Props
# Rushing Props
# Touchdown Props
# Defense/Special Teams Props
# Game Props
# Punt Props
# Sack Props
# Defensive Player Props
# Field Goal Props

# %%
#Sample market in Receiving Props
bets[4]['markets'][0]
# Out:
# {'id': '171031844',
#  'descriptionKey': 'Who will record the most Receiving Yards in the Game?',
#  'description': 'Who will record the most Receiving Yards in the Game?',
#  'key': 'GAME-PROP',
#  'marketTypeId': '-2804',
#  'status': 'O',
#  'singleOnly': False,
#  'notes': 'All wagers have action. Listed competitors only.',
#  'period': {'id': '119',
#   'description': 'Game',
#   'abbreviation': 'G',
#   'live': False,
#   'main': True},
#  'outcomes': [{'id': '923149676',
#    'description': 'Chris Carson (SEA)',
#    'status': 'O',
#    'type': 'X',
#    'competitorId': '9180627-11909483',
#    'price': {'id': '8787594366',
#     'american': '+5000',
#     'decimal': '51.00',
#     'fractional': '50/1',
#     'malay': '-0.02',
#     'indonesian': '50.00',
#     'hongkong': '50.00'}},
#   {'id': '923149677',
#    'description': 'DK Metcalf (SEA)',
#    'status': 'O',
#    'type': 'X',
#    'competitorId': '9180627-16115489',
#    'price': {'id': '8787598059',
#     'american': '+175',
#     'decimal': '2.750',
#     'fractional': '7/4',
#     'malay': '-0.57',
#     'indonesian': '1.75',
#     'hongkong': '1.75'}},
#   {'id': '923149678',
#    'description': 'Freddie Swain (SEA)',
#    'status': 'O',
#    'type': 'X',
#    'competitorId': '9180627-16429123',
#    'price': {'id': '8787594364',
#     'american': '+4500',
#     'decimal': '46.00',
#     'fractional': '45/1',
#     'malay': '-0.02',
#     'indonesian': '45.00',
#     'hongkong': '45.00'}},
#   {'id': '923149679',
#    'description': 'Gerald Everett (SEA)',
#    'status': 'O',
#    'type': 'X',
#    'competitorId': '9180627-16504323',
#    'price': {'id': '8787594365',
#     'american': '+4000',
#     'decimal': '41.00',
#     'fractional': '40/1',
#     'malay': '-0.03',
#     'indonesian': '40.00',
#     'hongkong': '40.00'}},
#   {'id': '923149680',
#    'description': 'Tyler Lockett (SEA)',
#    'status': 'O',
#    'type': 'X',
#    'competitorId': '9180627-216228',
#    'price': {'id': '8787598058',
#     'american': '+225',
#     'decimal': '3.250',
#     'fractional': '9/4',
#     'malay': '-0.44',
#     'indonesian': '2.25',
#     'hongkong': '2.25'}},
#   {'id': '923149681',
#    'description': 'Will Dissly (SEA)',
#    'status': 'O',
#    'type': 'X',
#    'competitorId': '9180627-11912670',
#    'price': {'id': '8787594363',
#     'american': '+4000',
#     'decimal': '41.00',
#     'fractional': '40/1',
#     'malay': '-0.03',
#     'indonesian': '40.00',
#     'hongkong': '40.00'}},
#   {'id': '923149682',
#    'description': 'Cooper Kupp (LA)',
#    'status': 'O',
#    'type': 'X',
#    'competitorId': '9180627-16309714',
#    'price': {'id': '8787598057',
#     'american': 'EVEN',
#     'decimal': '2.00',
#     'fractional': '1/1',
#     'malay': '1.00',
#     'indonesian': '1.00',
#     'hongkong': '1.00'}},
#   {'id': '923149683',
#    'description': 'Darrell Henderson Jr. (LA)',
#    'status': 'O',
#    'type': 'X',
#    'competitorId': '9180627-16114189',
#    'price': {'id': '8787594361',
#     'american': '+3500',
#     'decimal': '36.00',
#     'fractional': '35/1',
#     'malay': '-0.03',
#     'indonesian': '35.00',
#     'hongkong': '35.00'}},
#   {'id': '923149684',
#    'description': 'DeSean Jackson (LA)',
#    'status': 'O',
#    'type': 'X',
#    'competitorId': '9180627-16504256',
#    'price': {'id': '8787594358',
#     'american': '+2000',
#     'decimal': '21.00',
#     'fractional': '20/1',
#     'malay': '-0.05',
#     'indonesian': '20.00',
#     'hongkong': '20.00'}},
#   {'id': '923149685',
#    'description': 'Robert Woods (LA)',
#    'status': 'O',
#    'type': 'X',
#    'competitorId': '9180627-16309711',
#    'price': {'id': '8787598056',
#     'american': '+600',
#     'decimal': '7.00',
#     'fractional': '6/1',
#     'malay': '-0.17',
#     'indonesian': '6.00',
#     'hongkong': '6.00'}},
#   {'id': '923149686',
#    'description': 'Tyler Higbee (LA)',
#    'status': 'O',
#    'type': 'X',
#    'competitorId': '9180627-16309715',
#    'price': {'id': '8787594356',
#     'american': '+1500',
#     'decimal': '16.00',
#     'fractional': '15/1',
#     'malay': '-0.07',
#     'indonesian': '15.00',
#     'hongkong': '15.00'}},
#   {'id': '923149687',
#    'description': 'Van Jefferson (LA)',
#    'status': 'O',
#    'type': 'X',
#    'competitorId': '9180627-16427222',
#    'price': {'id': '8787594357',
#     'american': '+1500',
#     'decimal': '16.00',
#     'fractional': '15/1',
#     'malay': '-0.07',
#     'indonesian': '15.00',
#     'hongkong': '15.00'}}]}

# %%
#Push to dataframe for export
import pandas as pd
pd.set_option('display.max_rows', 500)
df = pd.DataFrame()
games = data[0]['events']
for n in range(len(games)):
    game_n = games[n]
    bets = game_n['displayGroups']
    important_markets = ['Receiving Props','Rushing Props','Quarterback Props']
    for market in important_markets:
        market_bets = [x for x in bets if x['description'] == market]
        if len(market_bets):
            markets = market_bets[0]['markets']
            for specific_market in markets:
                description = specific_market['description']
                if '-' not in description:
                    print("Not a player market - Description: %s"%description)
                else:
                    stat = description.split('-')[0].strip()
                    player = description.split('-')[1].strip()
                    if len(specific_market['outcomes']):
                        df.loc[player,stat] = specific_market['outcomes'][0]['price']['handicap']
                    else:
                        print("No outcomes for %s"%player)
# Out:
# Not a player market - Description: Who will record the most Receiving Yards in the Game?
# No outcomes for Damiere Byrd (CHI)

# %%
df
# Out:
#                             Total Receiving Yards Total Receptions  \
# Cooper Kupp (LA)                             85.5              6.5
# Darrell Henderson Jr. (LA)                   20.5              2.5
# DeSean Jackson (LA)                          23.5              1.5
# DK Metcalf (SEA)                             75.5              5.5
# Freddie Swain (SEA)                          19.5              2.0
# Robert Woods (LA)                            60.5              5.0
# Tyler Higbee (LA)                            40.5              4.0
# Tyler Lockett (SEA)                          68.5              5.5
# Van Jefferson (LA)                           45.5              3.5
# Matthew Stafford (LA)                         NaN              NaN
# Russell Wilson (SEA)                          NaN              NaN
# Sony Michel (LA)                              NaN              NaN
# Corey Davis (NYJ)                            59.5              4.5
# Jamison Crowder (NYJ)                        50.5              4.5
# Calvin Ridley (ATL)                           NaN              NaN
# Cordarrelle Patterson (ATL)                   NaN              NaN
# Hayden Hurst (ATL)                            NaN              NaN
# Kyle Pitts (ATL)                              NaN              NaN
# Mike Davis (ATL)                              NaN              NaN
# Michael Carter (NYJ)                          NaN              NaN
# Ty Johnson (NYJ)                              NaN              NaN
# Zach Wilson (NYJ)                             NaN              NaN
# Matt Ryan (ATL)                               NaN              NaN
# Aaron Jones (GB)                             25.5              3.5
# AJ Dillon (GB)                                8.5              NaN
# Allen Lazard (GB)                            35.5              3.0
# C.J. Uzomah (CIN)                            26.5              3.0
# Davante Adams (GB)                           94.5              7.5
# Ja'Marr Chase (CIN)                          66.5              4.5
# Randall Cobb (GB)                            35.5              3.0
# Robert Tonyan (GB)                           33.5              3.5
# Tyler Boyd (CIN)                             59.5              5.5
# Aaron Rodgers (GB)                            NaN              NaN
# Joe Burrow (CIN)                              NaN              NaN
# Antonio Brown (TB)                           59.5              5.0
# Chris Godwin (TB)                            68.5              5.0
# DeVante Parker (MIA)                         55.5              4.5
# Jaylen Waddle (MIA)                          56.5              4.5
# Mike Evans (TB)                              68.5              5.0
# Mike Gesicki (MIA)                           42.5              4.0
# Jacoby Brissett (MIA)                         NaN              NaN
# Tom Brady (TB)                                NaN              NaN
# Jameis Winston (NO)                           NaN              NaN
# Taylor Heinicke (WAS)                         NaN              NaN
# D.J. Moore (CAR)                             89.5              6.5
# Dallas Goedert (PHI)                         36.5              3.0
# DeVonta Smith (PHI)                          63.5              4.5
# Jalen Reagor (PHI)                           35.5              2.5
# Miles Sanders (PHI)                          18.5              2.5
# Robby Anderson (CAR)                         49.5              4.0
# Zach Ertz (PHI)                              29.5              2.5
# Jalen Hurts (PHI)                             NaN              NaN
# Trevor Lawrence (JAC)                         NaN              NaN
# Allen Robinson (CHI)                         59.5              4.5
# Bryan Edwards (LV)                           40.5              3.0
# Cole Kmet (CHI)                              26.5              2.5
# Damien Williams (CHI)                        22.5              3.0
# Darnell Mooney (CHI)                         50.5              4.5
# Darren Waller (LV)                           70.5              6.0
# Henry Ruggs III (LV)                         50.5              3.0
# Hunter Renfrow (LV)                          49.5              4.5
# Justin Fields (CHI)                           NaN              NaN
# Derek Carr (LV)                               NaN              NaN
#
#                             Longest Reception Total Rushing Yards  \
# Cooper Kupp (LA)                         26.5                 NaN
# Darrell Henderson Jr. (LA)               10.5                66.5
# DeSean Jackson (LA)                      15.5                 NaN
# DK Metcalf (SEA)                         24.5                 NaN
# Freddie Swain (SEA)                      13.5                 NaN
# Robert Woods (LA)                        20.5                 NaN
# Tyler Higbee (LA)                         NaN                 NaN
# Tyler Lockett (SEA)                      25.5                 NaN
# Van Jefferson (LA)                       20.5                 NaN
# Matthew Stafford (LA)                     NaN                 5.5
# Russell Wilson (SEA)                      NaN                22.5
# Sony Michel (LA)                          NaN                22.5
# Corey Davis (NYJ)                        23.5                 NaN
# Jamison Crowder (NYJ)                    21.5                 NaN
# Calvin Ridley (ATL)                      25.5                 NaN
# Cordarrelle Patterson (ATL)              15.5                 NaN
# Hayden Hurst (ATL)                       10.5                 NaN
# Kyle Pitts (ATL)                         18.5                 NaN
# Mike Davis (ATL)                         10.5                44.5
# Michael Carter (NYJ)                      NaN                44.5
# Ty Johnson (NYJ)                          NaN                18.5
# Zach Wilson (NYJ)                         NaN                 9.5
# Matt Ryan (ATL)                           NaN                 NaN
# Aaron Jones (GB)                         12.5                65.5
# AJ Dillon (GB)                            NaN                30.5
# Allen Lazard (GB)                        17.5                 NaN
# C.J. Uzomah (CIN)                        14.5                 NaN
# Davante Adams (GB)                       27.5                 NaN
# Ja'Marr Chase (CIN)                      24.5                 NaN
# Randall Cobb (GB)                        17.5                 NaN
# Robert Tonyan (GB)                       15.5                 NaN
# Tyler Boyd (CIN)                         20.5                 NaN
# Aaron Rodgers (GB)                        NaN                 5.5
# Joe Burrow (CIN)                          NaN                 6.5
# Antonio Brown (TB)                       22.5                 NaN
# Chris Godwin (TB)                        23.5                 NaN
# DeVante Parker (MIA)                     19.5                 NaN
# Jaylen Waddle (MIA)                      22.5                 NaN
# Mike Evans (TB)                          24.5                 NaN
# Mike Gesicki (MIA)                       17.5                 NaN
# Jacoby Brissett (MIA)                     NaN                 NaN
# Tom Brady (TB)                            NaN                 NaN
# Jameis Winston (NO)                       NaN                 NaN
# Taylor Heinicke (WAS)                     NaN                 NaN
# D.J. Moore (CAR)                         27.5                 NaN
# Dallas Goedert (PHI)                     16.5                 NaN
# DeVonta Smith (PHI)                      24.5                 NaN
# Jalen Reagor (PHI)                       16.5                 NaN
# Miles Sanders (PHI)                      11.5                46.5
# Robby Anderson (CAR)                     20.5                 NaN
# Zach Ertz (PHI)                          15.5                 NaN
# Jalen Hurts (PHI)                         NaN                47.5
# Trevor Lawrence (JAC)                     NaN                 NaN
# Allen Robinson (CHI)                     21.5                 NaN
# Bryan Edwards (LV)                       20.5                 NaN
# Cole Kmet (CHI)                          13.5                 NaN
# Damien Williams (CHI)                    11.5                60.5
# Darnell Mooney (CHI)                     20.5                 NaN
# Darren Waller (LV)                       22.5                 NaN
# Henry Ruggs III (LV)                     23.5                 NaN
# Hunter Renfrow (LV)                      19.5                 NaN
# Justin Fields (CHI)                       NaN                28.5
# Derek Carr (LV)                           NaN                 NaN
#
#                             Total Rushing and Receiving Yards  \
# Cooper Kupp (LA)                                          NaN
# Darrell Henderson Jr. (LA)                               90.5
# DeSean Jackson (LA)                                       NaN
# DK Metcalf (SEA)                                          NaN
# Freddie Swain (SEA)                                       NaN
# Robert Woods (LA)                                         NaN
# Tyler Higbee (LA)                                         NaN
# Tyler Lockett (SEA)                                       NaN
# Van Jefferson (LA)                                        NaN
# Matthew Stafford (LA)                                     NaN
# Russell Wilson (SEA)                                      NaN
# Sony Michel (LA)                                          NaN
# Corey Davis (NYJ)                                         NaN
# Jamison Crowder (NYJ)                                     NaN
# Calvin Ridley (ATL)                                       NaN
# Cordarrelle Patterson (ATL)                               NaN
# Hayden Hurst (ATL)                                        NaN
# Kyle Pitts (ATL)                                          NaN
# Mike Davis (ATL)                                         65.5
# Michael Carter (NYJ)                                     54.5
# Ty Johnson (NYJ)                                         26.5
# Zach Wilson (NYJ)                                         NaN
# Matt Ryan (ATL)                                           NaN
# Aaron Jones (GB)                                         95.5
# AJ Dillon (GB)                                           40.5
# Allen Lazard (GB)                                         NaN
# C.J. Uzomah (CIN)                                         NaN
# Davante Adams (GB)                                        NaN
# Ja'Marr Chase (CIN)                                       NaN
# Randall Cobb (GB)                                         NaN
# Robert Tonyan (GB)                                        NaN
# Tyler Boyd (CIN)                                          NaN
# Aaron Rodgers (GB)                                        NaN
# Joe Burrow (CIN)                                          NaN
# Antonio Brown (TB)                                        NaN
# Chris Godwin (TB)                                         NaN
# DeVante Parker (MIA)                                      NaN
# Jaylen Waddle (MIA)                                       NaN
# Mike Evans (TB)                                           NaN
# Mike Gesicki (MIA)                                        NaN
# Jacoby Brissett (MIA)                                     NaN
# Tom Brady (TB)                                            NaN
# Jameis Winston (NO)                                       NaN
# Taylor Heinicke (WAS)                                     NaN
# D.J. Moore (CAR)                                          NaN
# Dallas Goedert (PHI)                                      NaN
# DeVonta Smith (PHI)                                       NaN
# Jalen Reagor (PHI)                                        NaN
# Miles Sanders (PHI)                                       NaN
# Robby Anderson (CAR)                                      NaN
# Zach Ertz (PHI)                                           NaN
# Jalen Hurts (PHI)                                         NaN
# Trevor Lawrence (JAC)                                     NaN
# Allen Robinson (CHI)                                      NaN
# Bryan Edwards (LV)                                        NaN
# Cole Kmet (CHI)                                           NaN
# Damien Williams (CHI)                                    88.5
# Darnell Mooney (CHI)                                      NaN
# Darren Waller (LV)                                        NaN
# Henry Ruggs III (LV)                                      NaN
# Hunter Renfrow (LV)                                       NaN
# Justin Fields (CHI)                                       NaN
# Derek Carr (LV)                                           NaN
#
#                             Total Yards on 1st Rushing Attempt  \
# Cooper Kupp (LA)                                           NaN
# Darrell Henderson Jr. (LA)                                 3.5
# DeSean Jackson (LA)                                        NaN
# DK Metcalf (SEA)                                           NaN
# Freddie Swain (SEA)                                        NaN
# Robert Woods (LA)                                          NaN
# Tyler Higbee (LA)                                          NaN
# Tyler Lockett (SEA)                                        NaN
# Van Jefferson (LA)                                         NaN
# Matthew Stafford (LA)                                      NaN
# Russell Wilson (SEA)                                       NaN
# Sony Michel (LA)                                           NaN
# Corey Davis (NYJ)                                          NaN
# Jamison Crowder (NYJ)                                      NaN
# Calvin Ridley (ATL)                                        NaN
# Cordarrelle Patterson (ATL)                                NaN
# Hayden Hurst (ATL)                                         NaN
# Kyle Pitts (ATL)                                           NaN
# Mike Davis (ATL)                                           NaN
# Michael Carter (NYJ)                                       NaN
# Ty Johnson (NYJ)                                           NaN
# Zach Wilson (NYJ)                                          NaN
# Matt Ryan (ATL)                                            NaN
# Aaron Jones (GB)                                           3.5
# AJ Dillon (GB)                                             NaN
# Allen Lazard (GB)                                          NaN
# C.J. Uzomah (CIN)                                          NaN
# Davante Adams (GB)                                         NaN
# Ja'Marr Chase (CIN)                                        NaN
# Randall Cobb (GB)                                          NaN
# Robert Tonyan (GB)                                         NaN
# Tyler Boyd (CIN)                                           NaN
# Aaron Rodgers (GB)                                         NaN
# Joe Burrow (CIN)                                           NaN
# Antonio Brown (TB)                                         NaN
# Chris Godwin (TB)                                          NaN
# DeVante Parker (MIA)                                       NaN
# Jaylen Waddle (MIA)                                        NaN
# Mike Evans (TB)                                            NaN
# Mike Gesicki (MIA)                                         NaN
# Jacoby Brissett (MIA)                                      NaN
# Tom Brady (TB)                                             NaN
# Jameis Winston (NO)                                        NaN
# Taylor Heinicke (WAS)                                      NaN
# D.J. Moore (CAR)                                           NaN
# Dallas Goedert (PHI)                                       NaN
# DeVonta Smith (PHI)                                        NaN
# Jalen Reagor (PHI)                                         NaN
# Miles Sanders (PHI)                                        NaN
# Robby Anderson (CAR)                                       NaN
# Zach Ertz (PHI)                                            NaN
# Jalen Hurts (PHI)                                          NaN
# Trevor Lawrence (JAC)                                      NaN
# Allen Robinson (CHI)                                       NaN
# Bryan Edwards (LV)                                         NaN
# Cole Kmet (CHI)                                            NaN
# Damien Williams (CHI)                                      NaN
# Darnell Mooney (CHI)                                       NaN
# Darren Waller (LV)                                         NaN
# Henry Ruggs III (LV)                                       NaN
# Hunter Renfrow (LV)                                        NaN
# Justin Fields (CHI)                                        NaN
# Derek Carr (LV)                                            NaN
#
#                             Total Rushing Attempts in the game  \
# Cooper Kupp (LA)                                           NaN
# Darrell Henderson Jr. (LA)                                14.5
# DeSean Jackson (LA)                                        NaN
# DK Metcalf (SEA)                                           NaN
# Freddie Swain (SEA)                                        NaN
# Robert Woods (LA)                                          NaN
# Tyler Higbee (LA)                                          NaN
# Tyler Lockett (SEA)                                        NaN
# Van Jefferson (LA)                                         NaN
# Matthew Stafford (LA)                                      NaN
# Russell Wilson (SEA)                                       NaN
# Sony Michel (LA)                                           NaN
# Corey Davis (NYJ)                                          NaN
# Jamison Crowder (NYJ)                                      NaN
# Calvin Ridley (ATL)                                        NaN
# Cordarrelle Patterson (ATL)                                NaN
# Hayden Hurst (ATL)                                         NaN
# Kyle Pitts (ATL)                                           NaN
# Mike Davis (ATL)                                           NaN
# Michael Carter (NYJ)                                       NaN
# Ty Johnson (NYJ)                                           NaN
# Zach Wilson (NYJ)                                          NaN
# Matt Ryan (ATL)                                            NaN
# Aaron Jones (GB)                                          14.5
# AJ Dillon (GB)                                             7.5
# Allen Lazard (GB)                                          NaN
# C.J. Uzomah (CIN)                                          NaN
# Davante Adams (GB)                                         NaN
# Ja'Marr Chase (CIN)                                        NaN
# Randall Cobb (GB)                                          NaN
# Robert Tonyan (GB)                                         NaN
# Tyler Boyd (CIN)                                           NaN
# Aaron Rodgers (GB)                                         NaN
# Joe Burrow (CIN)                                           NaN
# Antonio Brown (TB)                                         NaN
# Chris Godwin (TB)                                          NaN
# DeVante Parker (MIA)                                       NaN
# Jaylen Waddle (MIA)                                        NaN
# Mike Evans (TB)                                            NaN
# Mike Gesicki (MIA)                                         NaN
# Jacoby Brissett (MIA)                                      NaN
# Tom Brady (TB)                                             NaN
# Jameis Winston (NO)                                        NaN
# Taylor Heinicke (WAS)                                      NaN
# D.J. Moore (CAR)                                           NaN
# Dallas Goedert (PHI)                                       NaN
# DeVonta Smith (PHI)                                        NaN
# Jalen Reagor (PHI)                                         NaN
# Miles Sanders (PHI)                                       11.5
# Robby Anderson (CAR)                                       NaN
# Zach Ertz (PHI)                                            NaN
# Jalen Hurts (PHI)                                          7.5
# Trevor Lawrence (JAC)                                      NaN
# Allen Robinson (CHI)                                       NaN
# Bryan Edwards (LV)                                         NaN
# Cole Kmet (CHI)                                            NaN
# Damien Williams (CHI)                                      NaN
# Darnell Mooney (CHI)                                       NaN
# Darren Waller (LV)                                         NaN
# Henry Ruggs III (LV)                                       NaN
# Hunter Renfrow (LV)                                        NaN
# Justin Fields (CHI)                                        NaN
# Derek Carr (LV)                                            NaN
#
#                             Total Passing Yards  \
# Cooper Kupp (LA)                            NaN
# Darrell Henderson Jr. (LA)                  NaN
# DeSean Jackson (LA)                         NaN
# DK Metcalf (SEA)                            NaN
# Freddie Swain (SEA)                         NaN
# Robert Woods (LA)                           NaN
# Tyler Higbee (LA)                           NaN
# Tyler Lockett (SEA)                         NaN
# Van Jefferson (LA)                          NaN
# Matthew Stafford (LA)                     300.5
# Russell Wilson (SEA)                      275.5
# Sony Michel (LA)                            NaN
# Corey Davis (NYJ)                           NaN
# Jamison Crowder (NYJ)                       NaN
# Calvin Ridley (ATL)                         NaN
# Cordarrelle Patterson (ATL)                 NaN
# Hayden Hurst (ATL)                          NaN
# Kyle Pitts (ATL)                            NaN
# Mike Davis (ATL)                            NaN
# Michael Carter (NYJ)                        NaN
# Ty Johnson (NYJ)                            NaN
# Zach Wilson (NYJ)                         245.5
# Matt Ryan (ATL)                             NaN
# Aaron Jones (GB)                            NaN
# AJ Dillon (GB)                              NaN
# Allen Lazard (GB)                           NaN
# C.J. Uzomah (CIN)                           NaN
# Davante Adams (GB)                          NaN
# Ja'Marr Chase (CIN)                         NaN
# Randall Cobb (GB)                           NaN
# Robert Tonyan (GB)                          NaN
# Tyler Boyd (CIN)                            NaN
# Aaron Rodgers (GB)                        270.5
# Joe Burrow (CIN)                          265.5
# Antonio Brown (TB)                          NaN
# Chris Godwin (TB)                           NaN
# DeVante Parker (MIA)                        NaN
# Jaylen Waddle (MIA)                         NaN
# Mike Evans (TB)                             NaN
# Mike Gesicki (MIA)                          NaN
# Jacoby Brissett (MIA)                     240.5
# Tom Brady (TB)                            305.5
# Jameis Winston (NO)                       210.5
# Taylor Heinicke (WAS)                     245.5
# D.J. Moore (CAR)                            NaN
# Dallas Goedert (PHI)                        NaN
# DeVonta Smith (PHI)                         NaN
# Jalen Reagor (PHI)                          NaN
# Miles Sanders (PHI)                         NaN
# Robby Anderson (CAR)                        NaN
# Zach Ertz (PHI)                             NaN
# Jalen Hurts (PHI)                         240.5
# Trevor Lawrence (JAC)                     249.5
# Allen Robinson (CHI)                        NaN
# Bryan Edwards (LV)                          NaN
# Cole Kmet (CHI)                             NaN
# Damien Williams (CHI)                       NaN
# Darnell Mooney (CHI)                        NaN
# Darren Waller (LV)                          NaN
# Henry Ruggs III (LV)                        NaN
# Hunter Renfrow (LV)                         NaN
# Justin Fields (CHI)                       210.5
# Derek Carr (LV)                           280.5
#
#                             Total Passing Attempts in the game  \
# Cooper Kupp (LA)                                           NaN
# Darrell Henderson Jr. (LA)                                 NaN
# DeSean Jackson (LA)                                        NaN
# DK Metcalf (SEA)                                           NaN
# Freddie Swain (SEA)                                        NaN
# Robert Woods (LA)                                          NaN
# Tyler Higbee (LA)                                          NaN
# Tyler Lockett (SEA)                                        NaN
# Van Jefferson (LA)                                         NaN
# Matthew Stafford (LA)                                     37.5
# Russell Wilson (SEA)                                      34.5
# Sony Michel (LA)                                           NaN
# Corey Davis (NYJ)                                          NaN
# Jamison Crowder (NYJ)                                      NaN
# Calvin Ridley (ATL)                                        NaN
# Cordarrelle Patterson (ATL)                                NaN
# Hayden Hurst (ATL)                                         NaN
# Kyle Pitts (ATL)                                           NaN
# Mike Davis (ATL)                                           NaN
# Michael Carter (NYJ)                                       NaN
# Ty Johnson (NYJ)                                           NaN
# Zach Wilson (NYJ)                                         34.5
# Matt Ryan (ATL)                                           37.0
# Aaron Jones (GB)                                           NaN
# AJ Dillon (GB)                                             NaN
# Allen Lazard (GB)                                          NaN
# C.J. Uzomah (CIN)                                          NaN
# Davante Adams (GB)                                         NaN
# Ja'Marr Chase (CIN)                                        NaN
# Randall Cobb (GB)                                          NaN
# Robert Tonyan (GB)                                         NaN
# Tyler Boyd (CIN)                                           NaN
# Aaron Rodgers (GB)                                        34.5
# Joe Burrow (CIN)                                          34.5
# Antonio Brown (TB)                                         NaN
# Chris Godwin (TB)                                          NaN
# DeVante Parker (MIA)                                       NaN
# Jaylen Waddle (MIA)                                        NaN
# Mike Evans (TB)                                            NaN
# Mike Gesicki (MIA)                                         NaN
# Jacoby Brissett (MIA)                                     36.5
# Tom Brady (TB)                                            39.5
# Jameis Winston (NO)                                        NaN
# Taylor Heinicke (WAS)                                      NaN
# D.J. Moore (CAR)                                           NaN
# Dallas Goedert (PHI)                                       NaN
# DeVonta Smith (PHI)                                        NaN
# Jalen Reagor (PHI)                                         NaN
# Miles Sanders (PHI)                                        NaN
# Robby Anderson (CAR)                                       NaN
# Zach Ertz (PHI)                                            NaN
# Jalen Hurts (PHI)                                         31.5
# Trevor Lawrence (JAC)                                     34.5
# Allen Robinson (CHI)                                       NaN
# Bryan Edwards (LV)                                         NaN
# Cole Kmet (CHI)                                            NaN
# Damien Williams (CHI)                                      NaN
# Darnell Mooney (CHI)                                       NaN
# Darren Waller (LV)                                         NaN
# Henry Ruggs III (LV)                                       NaN
# Hunter Renfrow (LV)                                        NaN
# Justin Fields (CHI)                                       29.5
# Derek Carr (LV)                                           33.5
#
#                             Total Touchdown Passes Total Completions  \
# Cooper Kupp (LA)                               NaN               NaN
# Darrell Henderson Jr. (LA)                     NaN               NaN
# DeSean Jackson (LA)                            NaN               NaN
# DK Metcalf (SEA)                               NaN               NaN
# Freddie Swain (SEA)                            NaN               NaN
# Robert Woods (LA)                              NaN               NaN
# Tyler Higbee (LA)                              NaN               NaN
# Tyler Lockett (SEA)                            NaN               NaN
# Van Jefferson (LA)                             NaN               NaN
# Matthew Stafford (LA)                          2.5              25.5
# Russell Wilson (SEA)                           1.5              24.5
# Sony Michel (LA)                               NaN               NaN
# Corey Davis (NYJ)                              NaN               NaN
# Jamison Crowder (NYJ)                          NaN               NaN
# Calvin Ridley (ATL)                            NaN               NaN
# Cordarrelle Patterson (ATL)                    NaN               NaN
# Hayden Hurst (ATL)                             NaN               NaN
# Kyle Pitts (ATL)                               NaN               NaN
# Mike Davis (ATL)                               NaN               NaN
# Michael Carter (NYJ)                           NaN               NaN
# Ty Johnson (NYJ)                               NaN               NaN
# Zach Wilson (NYJ)                              1.5              21.5
# Matt Ryan (ATL)                                1.5              24.5
# Aaron Jones (GB)                               NaN               NaN
# AJ Dillon (GB)                                 NaN               NaN
# Allen Lazard (GB)                              NaN               NaN
# C.J. Uzomah (CIN)                              NaN               NaN
# Davante Adams (GB)                             NaN               NaN
# Ja'Marr Chase (CIN)                            NaN               NaN
# Randall Cobb (GB)                              NaN               NaN
# Robert Tonyan (GB)                             NaN               NaN
# Tyler Boyd (CIN)                               NaN               NaN
# Aaron Rodgers (GB)                             2.5              24.0
# Joe Burrow (CIN)                               1.5              23.5
# Antonio Brown (TB)                             NaN               NaN
# Chris Godwin (TB)                              NaN               NaN
# DeVante Parker (MIA)                           NaN               NaN
# Jaylen Waddle (MIA)                            NaN               NaN
# Mike Evans (TB)                                NaN               NaN
# Mike Gesicki (MIA)                             NaN               NaN
# Jacoby Brissett (MIA)                          1.5              22.5
# Tom Brady (TB)                                 2.5              25.5
# Jameis Winston (NO)                            NaN               NaN
# Taylor Heinicke (WAS)                          NaN               NaN
# D.J. Moore (CAR)                               NaN               NaN
# Dallas Goedert (PHI)                           NaN               NaN
# DeVonta Smith (PHI)                            NaN               NaN
# Jalen Reagor (PHI)                             NaN               NaN
# Miles Sanders (PHI)                            NaN               NaN
# Robby Anderson (CAR)                           NaN               NaN
# Zach Ertz (PHI)                                NaN               NaN
# Jalen Hurts (PHI)                              1.5              20.5
# Trevor Lawrence (JAC)                          1.5              20.0
# Allen Robinson (CHI)                           NaN               NaN
# Bryan Edwards (LV)                             NaN               NaN
# Cole Kmet (CHI)                                NaN               NaN
# Damien Williams (CHI)                          NaN               NaN
# Darnell Mooney (CHI)                           NaN               NaN
# Darren Waller (LV)                             NaN               NaN
# Henry Ruggs III (LV)                           NaN               NaN
# Hunter Renfrow (LV)                            NaN               NaN
# Justin Fields (CHI)                            1.5              18.5
# Derek Carr (LV)                                1.5              23.5
#
#                             Longest Completion Total Interceptions Thrown
# Cooper Kupp (LA)                           NaN                        NaN
# Darrell Henderson Jr. (LA)                 NaN                        NaN
# DeSean Jackson (LA)                        NaN                        NaN
# DK Metcalf (SEA)                           NaN                        NaN
# Freddie Swain (SEA)                        NaN                        NaN
# Robert Woods (LA)                          NaN                        NaN
# Tyler Higbee (LA)                          NaN                        NaN
# Tyler Lockett (SEA)                        NaN                        NaN
# Van Jefferson (LA)                         NaN                        NaN
# Matthew Stafford (LA)                     39.5                        0.5
# Russell Wilson (SEA)                      38.5                        0.5
# Sony Michel (LA)                           NaN                        NaN
# Corey Davis (NYJ)                          NaN                        NaN
# Jamison Crowder (NYJ)                      NaN                        NaN
# Calvin Ridley (ATL)                        NaN                        NaN
# Cordarrelle Patterson (ATL)                NaN                        NaN
# Hayden Hurst (ATL)                         NaN                        NaN
# Kyle Pitts (ATL)                           NaN                        NaN
# Mike Davis (ATL)                           NaN                        NaN
# Michael Carter (NYJ)                       NaN                        NaN
# Ty Johnson (NYJ)                           NaN                        NaN
# Zach Wilson (NYJ)                         36.5                        1.5
# Matt Ryan (ATL)                           37.5                        0.5
# Aaron Jones (GB)                           NaN                        NaN
# AJ Dillon (GB)                             NaN                        NaN
# Allen Lazard (GB)                          NaN                        NaN
# C.J. Uzomah (CIN)                          NaN                        NaN
# Davante Adams (GB)                         NaN                        NaN
# Ja'Marr Chase (CIN)                        NaN                        NaN
# Randall Cobb (GB)                          NaN                        NaN
# Robert Tonyan (GB)                         NaN                        NaN
# Tyler Boyd (CIN)                           NaN                        NaN
# Aaron Rodgers (GB)                        37.5                        0.5
# Joe Burrow (CIN)                          37.5                        0.5
# Antonio Brown (TB)                         NaN                        NaN
# Chris Godwin (TB)                          NaN                        NaN
# DeVante Parker (MIA)                       NaN                        NaN
# Jaylen Waddle (MIA)                        NaN                        NaN
# Mike Evans (TB)                            NaN                        NaN
# Mike Gesicki (MIA)                         NaN                        NaN
# Jacoby Brissett (MIA)                     34.5                        0.5
# Tom Brady (TB)                            39.5                        0.5
# Jameis Winston (NO)                        NaN                        NaN
# Taylor Heinicke (WAS)                      NaN                        NaN
# D.J. Moore (CAR)                           NaN                        NaN
# Dallas Goedert (PHI)                       NaN                        NaN
# DeVonta Smith (PHI)                        NaN                        NaN
# Jalen Reagor (PHI)                         NaN                        NaN
# Miles Sanders (PHI)                        NaN                        NaN
# Robby Anderson (CAR)                       NaN                        NaN
# Zach Ertz (PHI)                            NaN                        NaN
# Jalen Hurts (PHI)                          NaN                        0.5
# Trevor Lawrence (JAC)                      NaN                        0.5
# Allen Robinson (CHI)                       NaN                        NaN
# Bryan Edwards (LV)                         NaN                        NaN
# Cole Kmet (CHI)                            NaN                        NaN
# Damien Williams (CHI)                      NaN                        NaN
# Darnell Mooney (CHI)                       NaN                        NaN
# Darren Waller (LV)                         NaN                        NaN
# Henry Ruggs III (LV)                       NaN                        NaN
# Hunter Renfrow (LV)                        NaN                        NaN
# Justin Fields (CHI)                       34.5                        0.5
# Derek Carr (LV)                           39.5                        0.5
